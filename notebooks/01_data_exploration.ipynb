# %% [markdown]
# # DESI DR1 BAO Data Exploration
#
# This notebook explores the DESI DR1 BAO measurements and validates
# our likelihood implementation against known results.

# %%
import numpy as np
import matplotlib.pyplot as plt
from desi_ft.models.lcdm import LCDM
from desi_ft.likelihoods.bao import BAOLikelihood
